# %%
import pandas as pd
from datetime import date # para pegar a data corrente
import pyodbc 


#server = '.' # Nesta instalação pode ser tanto "." como "RENATO-DESKTOP"
server = 'localhost'    # Substitua pelo nome do servidor SQL Server
database = 'Python'     # Substitua pelo nome do banco de dados
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'
                      'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()   # criando cursor de comando

# %%
#pip install pandas
#pip install pyodbc
#pip install selenium
#pip install lxml

# %%
dados = pd.read_sql("""
    SELECT * FROM fundamentus_fii
    WHERE (Dividend_yield between 0.07 and 0.12) and
          (PVP between 0.7 and 1) and
          (Liquidez > 500000) and
          Dia = ?
""", conexaoDB, params=[date.today()])

dados.head(50)
# Out:
# C:\Users\Renato\AppData\Local\Temp\ipykernel_7864\2395841580.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dados = pd.read_sql("""
#            Dia       Papel        Segmento  Cotacao  FFO_yield  \
# 0   2026-05-08  ALZR11      Multicategoria    10.59     0.0813
# 1   2026-05-08  AZPL11           Logística     7.76     0.0713
# 2   2026-05-08  BCIA11      Multicategoria    92.42     0.1190
# 3   2026-05-08  BLMO11         Escritórios    88.49     0.0691
# 4   2026-05-08  BTAL11           Logística    89.93     0.1265
# 5   2026-05-08  FGAA11              Outros     9.17     0.1442
# 6   2026-05-08  GARE11      Multicategoria     8.28     0.0373
# 7   2026-05-08  GGRC11      Multicategoria    10.20     0.0698
# 8   2026-05-08  HFOF11      Multicategoria     6.71     0.1047
# 9   2026-05-08  HGBS11           Shoppings    20.35     0.0805
# 10  2026-05-08  HGLG11      Multicategoria   155.98     0.0659
# 11  2026-05-08  HGRE11         Escritórios   130.43     0.0692
# 12  2026-05-08  HPDP11           Shoppings    89.57     0.0761
# 13  2026-05-08  HSLG11           Logística    93.10     0.0959
# 14  2026-05-08  HSML11           Shoppings    93.63     0.0674
# 15  2026-05-08  IBBP11           Logística     8.10     0.0878
# 16  2026-05-08  ICRI11              Outros    99.90     0.1258
# 17  2026-05-08  ITRI11              Outros    86.71     0.1153
# 18  2026-05-08  KFOF11      Multicategoria    83.33     0.1177
# 19  2026-05-08  KNIP11      Multicategoria    93.60     0.1183
# 20  2026-05-08  LVBI11           Logística   109.15     0.0828
# 21  2026-05-08  MALL11           Shoppings   100.03     0.1422
# 22  2026-05-08  MCLO11           Logística     9.91     0.0933
# 23  2026-05-08  PATL11      Multicategoria    64.63     0.1099
# 24  2026-05-08  PLAG11              Outros    64.52     0.0894
# 25  2026-05-08  PMLL11           Shoppings   108.34     0.1263
# 26  2026-05-08  PQAG11           Logística    52.50     0.1091
# 27  2026-05-08  PVBI11         Escritórios    75.50     0.0749
# 28  2026-05-08  RBRL11           Logística    85.00     0.0840
# 29  2026-05-08  RBRR11      Multicategoria    84.40     0.0879
# 30  2026-05-08  RBVA11              Varejo     9.79     0.0703
# 31  2026-05-08  RCRB11         Escritórios   140.57     0.0489
# 32  2026-05-08  TRBL11           Logística    75.64     0.0531
# 33  2026-05-08  VILG11           Logística   101.26     0.0794
# 34  2026-05-08  VISC11           Shoppings   111.14     0.0864
# 35  2026-05-08  XPLG11           Logística    99.92     0.0722
# 36  2026-05-08  XPML11           Shoppings   110.58     0.0778
#
#     Dividend_yield   PVP  Valor_mercado  Liquidez  Qtd_imoveis  Preco_m2  \
# 0           0.0944  1.00     1486430000   2230350           23   3423.42
# 1           0.1186  0.90      325320000    617287            1   1580.20
